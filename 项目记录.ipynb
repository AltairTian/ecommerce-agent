# %% [markdown]
# 开发顺序
# 1. 环境
# 2. 数据库
# 3. SQL分析
# 4. 指标体系
# 5. 图表
# 6. Agent
# 7. Streamlit

# %% [markdown]
# ## 1. 环境

# %% [markdown]
# ## 2. 数据准备与处理
# （1）数据来源
#
# 本项目使用 Kaggle Brazilian E-Commerce Public Dataset by Olist，包含约10万条巴西电商订单数据，涵盖订单、客户、商品、支付、评价、卖家等信息。
#
# （2）创建数据库
#
# （3）建立宽表
# order_analysis_view 的所有属性：
# 1. order_id
# 2. customer_id
# 3. order_status
# 4. order_purchase_timestamp
# 5. order_approved_at
# 6. order_delivered_customer_date
# 7. order_estimated_delivery_date
# 8. customer_unique_id
# 9. customer_city
# 10. customer_state
#
# （4）通过宽表检查数据质量

# %% [markdown]
# ## 3. SQL分析
#
# GMV趋势
# 热销品类
# 地区销售
# 支付方式
# 评价分析
# 复购分析

# %% [markdown]
# 4. 指标体系

# %% [markdown]
# 5. 图表

# %% [markdown]
# 6. Agent

# %% [markdown]
# 7. Streamlit（前端界面）
